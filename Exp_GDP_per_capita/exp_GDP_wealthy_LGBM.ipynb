# %%
# !pip install lightgbm optuna
# !pip install optuna-integration[lightgbm]
import shap
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import json
import lightgbm as lgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import KFold
import optuna
from optuna.integration import LightGBMPruningCallback
import sys
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 386.6/386.6 kB 10.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.5/242.5 kB 11.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.5/98.5 kB 6.5 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import os
os.chdir('/content/drive/MyDrive/Senior_Thesis_Waseda/exp_GDP_per_capita')

# %%
# %run ../evaluation.ipynb
# %run ../training.ipynb
# %run ../parameter_optimization.ipynb

# %%
df = pd.read_csv('/content/drive/MyDrive/Senior_Thesis_Waseda/happiness_data.csv')
df.head()
df.shape
# Out:
# (97220, 82)

# %%
df = df[df['GDP group']==1]
df.shape
# Out:
# (34132, 82)

# %%
categorical = ['Cl_73','Cl_74','Cl_75','Cl_76']

for col in categorical:
    if col in df.columns:
        df[col] = df[col].astype('category')
# Out:
# <ipython-input-7-1827692732>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].astype('category')

# %%
X = df.loc[:, 'Cl_1':]
y = df['happiness']

# %%
parameter_optimization(X, y,
    save_path="exp_GDP_wealthy_best_params.json")
# Out:
# [I 2025-06-14 19:12:21,999] A new study created in memory with name: lgbm_regression_opt
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [210]	valid's rmse: 1.26325
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [217]	valid's rmse: 1.2679
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [251]	valid's rmse: 1.26442
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [199]	valid's rmse: 1.25735
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [322]	valid's rmse: 1.24513
# ...

# %%
model, test_rmse= training(X, y,
    params_json_path="exp_GDP_wealthy_best_params.json",
    save_model_path='exp_GDP_wealthy_model.txt',
    save_log_filename="exp_GDP_wealthy_log.csv")
# Out:
# Training until validation scores don't improve for 50 rounds
# [50]	valid's rmse: 1.42137	valid's l2: 2.02031
# [100]	valid's rmse: 1.30641	valid's l2: 1.70671
# [150]	valid's rmse: 1.27793	valid's l2: 1.6331
# [200]	valid's rmse: 1.26878	valid's l2: 1.60979
# [250]	valid's rmse: 1.26438	valid's l2: 1.59866
# [300]	valid's rmse: 1.2616	valid's l2: 1.59164
# [350]	valid's rmse: 1.26014	valid's l2: 1.58795
# [400]	valid's rmse: 1.25931	valid's l2: 1.58586
# [450]	valid's rmse: 1.25795	valid's l2: 1.58244
# [500]	valid's rmse: 1.25753	valid's l2: 1.58138
# [550]	valid's rmse: 1.25736	valid's l2: 1.58095
# Early stopping, best iteration is:
# [512]	valid's rmse: 1.25713	valid's l2: 1.58036

# %%
# Compute the standard deviation of y
std_y = y.std()
print(f"The standard deviation of y is: {std_y}")
# Out:
# The standard deviation of y is: 1.8792580310044618

# %%
evaluation(model,
    X.sample(10000),
    name = "exp_GDP_wealthy_results",
    max_display=30)
