# %%
# !pip install lightgbm optuna
# !pip install optuna-integration[lightgbm]
import shap
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import json
import lightgbm as lgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import KFold
import optuna
from optuna.integration import LightGBMPruningCallback
import sys
# Out:
# Requirement already satisfied: lightgbm in /usr/local/lib/python3.11/dist-packages (4.5.0)
# Collecting optuna
#   Downloading optuna-4.3.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from lightgbm) (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from lightgbm) (1.15.3)
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.16.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.9.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.41)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from optuna) (6.0.2)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic>=1.5.0->optuna) (1.1.3)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.11/dist-packages (from alembic>=1.5.0->optuna) (4.14.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.2.2)
# Downloading optuna-4.3.0-py3-none-any.whl (386 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 386.6/386.6 kB 7.6 MB/s eta 0:00:00
# Downloading alembic-1.16.1-py3-none-any.whl (242 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.5/242.5 kB 5.8 MB/s eta 0:00:00
# Downloading colorlog-6.9.0-py3-none-any.whl (11 kB)
# Installing collected packages: colorlog, alembic, optuna
# Successfully installed alembic-1.16.1 colorlog-6.9.0 optuna-4.3.0
# Collecting optuna-integration[lightgbm]
#   Downloading optuna_integration-4.3.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: optuna in /usr/local/lib/python3.11/dist-packages (from optuna-integration[lightgbm]) (4.3.0)
# Requirement already satisfied: lightgbm in /usr/local/lib/python3.11/dist-packages (from optuna-integration[lightgbm]) (4.5.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from optuna-integration[lightgbm]) (1.6.1)
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from lightgbm->optuna-integration[lightgbm]) (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from lightgbm->optuna-integration[lightgbm]) (1.15.3)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from optuna->optuna-integration[lightgbm]) (1.16.1)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.11/dist-packages (from optuna->optuna-integration[lightgbm]) (6.9.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from optuna->optuna-integration[lightgbm]) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from optuna->optuna-integration[lightgbm]) (2.0.41)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from optuna->optuna-integration[lightgbm]) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from optuna->optuna-integration[lightgbm]) (6.0.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->optuna-integration[lightgbm]) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->optuna-integration[lightgbm]) (3.6.0)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic>=1.5.0->optuna->optuna-integration[lightgbm]) (1.1.3)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.11/dist-packages (from alembic>=1.5.0->optuna->optuna-integration[lightgbm]) (4.14.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.2->optuna->optuna-integration[lightgbm]) (3.2.2)
# Downloading optuna_integration-4.3.0-py3-none-any.whl (98 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.5/98.5 kB 2.4 MB/s eta 0:00:00
# Installing collected packages: optuna-integration
# Successfully installed optuna-integration-4.3.0

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import os
os.chdir('/content/drive/MyDrive/Senior_Thesis_Waseda/exp_GDP_per_capita')

# %%
# %run ../evaluation.ipynb
# %run ../training.ipynb
# %run ../parameter_optimization.ipynb
# Out:
# Requirement already satisfied: lightgbm in /usr/local/lib/python3.11/dist-packages (4.5.0)
# Requirement already satisfied: optuna in /usr/local/lib/python3.11/dist-packages (4.3.0)
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from lightgbm) (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from lightgbm) (1.15.3)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (1.16.1)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.11/dist-packages (from optuna) (6.9.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.41)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from optuna) (6.0.2)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic>=1.5.0->optuna) (1.1.3)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.11/dist-packages (from alembic>=1.5.0->optuna) (4.14.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.2.2)
# Requirement already satisfied: optuna-integration[lightgbm] in /usr/local/lib/python3.11/dist-packages (4.3.0)
# Requirement already satisfied: optuna in /usr/local/lib/python3.11/dist-packages (from optuna-integration[lightgbm]) (4.3.0)
# Requirement already satisfied: lightgbm in /usr/local/lib/python3.11/dist-packages (from optuna-integration[lightgbm]) (4.5.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from optuna-integration[lightgbm]) (1.6.1)
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from lightgbm->optuna-integration[lightgbm]) (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from lightgbm->optuna-integration[lightgbm]) (1.15.3)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from optuna->optuna-integration[lightgbm]) (1.16.1)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.11/dist-packages (from optuna->optuna-integration[lightgbm]) (6.9.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from optuna->optuna-integration[lightgbm]) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from optuna->optuna-integration[lightgbm]) (2.0.41)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from optuna->optuna-integration[lightgbm]) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from optuna->optuna-integration[lightgbm]) (6.0.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->optuna-integration[lightgbm]) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->optuna-integration[lightgbm]) (3.6.0)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic>=1.5.0->optuna->optuna-integration[lightgbm]) (1.1.3)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.11/dist-packages (from alembic>=1.5.0->optuna->optuna-integration[lightgbm]) (4.14.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.2->optuna->optuna-integration[lightgbm]) (3.2.2)

# %%
df = pd.read_csv('/content/drive/MyDrive/Senior_Thesis_Waseda/happiness_data.csv')
df.head()
df.shape
# Out:
# (97220, 82)

# %%
df = df[df['GDP group']==0]
df.shape
# Out:
# (63088, 82)

# %%
categorical = ['Cl_73','Cl_74', 'Cl_75','Cl_76']

for col in categorical:
    if col in df.columns:
        df[col] = df[col].astype('category')
# Out:
# <ipython-input-7-1720271455>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].astype('category')

# %%
X = df.loc[:, 'Cl_1':]
y = df['happiness']

# %%
parameter_optimization(X, y,
    save_path="exp_GDP_poor_best_params.json")
# Out:
# [I 2025-06-14 19:19:54,188] A new study created in memory with name: lgbm_regression_opt
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [296]	valid's rmse: 1.60669
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [499]	valid's rmse: 1.60624
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [447]	valid's rmse: 1.58823
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [404]	valid's rmse: 1.5954
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [498]	valid's rmse: 1.61614
# [I 2025-06-14 19:21:05,943] Trial 0 finished with value: 1.602539978986303 and parameters: {'num_leaves': 37, 'learning_rate': 0.059662768998574464, 'max_depth': 12, 'reg_alpha': 0.01689821456403644, 'reg_lambda': 0.008733286960935062, 'feature_fraction': 0.5545578611806954, 'bagging_fraction': 0.7944205512826226, 'bagging_freq': 4, 'min_data_in_leaf': 483}. Best is trial 0 with value: 1.602539978986303.
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 1.6419
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 1.64322
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 1.63091
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 1.63304
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 1.6554
# [I 2025-06-14 19:22:06,367] Trial 1 finished with value: 1.640893848798943 and parameters: {'num_leaves': 124, 'learning_rate': 0.008135993077935482, 'max_depth': 11, 'reg_alpha': 0.00016165526881359486, 'reg_lambda': 0.7035409156988579, 'feature_fraction': 0.4019026700531766, 'bagging_fraction': 0.5756856352296862, 'bagging_freq': 5, 'min_data_in_leaf': 459}. Best is trial 0 with value: 1.602539978986303.
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 1.74182
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 1.74118
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 1.73944
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 1.73771
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 1.75285
# [I 2025-06-14 19:23:33,110] Trial 2 finished with value: 1.7426003878355671 and parameters: {'num_leaves': 59, 'learning_rate': 0.0031419355583659327, 'max_depth': 9, 'reg_alpha': 8.662924996503568, 'reg_lambda': 0.02194583099502228, 'feature_fraction': 0.47397242771581266, 'bagging_fraction': 0.9496188320394634, 'bagging_freq': 7, 'min_data_in_leaf': 153}. Best is trial 0 with value: 1.602539978986303.
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 1.81355
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 1.81515
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 1.81366
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 1.8148
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 1.82628
# [I 2025-06-14 19:24:21,649] Trial 3 finished with value: 1.8166871619860339 and parameters: {'num_leaves': 88, 'learning_rate': 0.0020393416894354194, 'max_depth': 3, 'reg_alpha': 0.004180382606157517, 'reg_lambda': 9.005175761589022, 'feature_fraction': 0.7078847726835956, 'bagging_fraction': 0.9258973847512997, 'bagging_freq': 1, 'min_data_in_leaf': 156}. Best is trial 0 with value: 1.602539978986303.
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 1.59433
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 1.60229
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [499]	valid's rmse: 1.5882
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [488]	valid's rmse: 1.59284
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [498]	valid's rmse: 1.61014
# [I 2025-06-14 19:26:23,293] Trial 4 finished with value: 1.5975577796019256 and parameters: {'num_leaves': 81, 'learning_rate': 0.03338461566965746, 'max_depth': 12, 'reg_alpha': 0.009228237972087388, 'reg_lambda': 4.420164028591646, 'feature_fraction': 0.6997672062599631, 'bagging_fraction': 0.8812298141809676, 'bagging_freq': 7, 'min_data_in_leaf': 251}. Best is trial 4 with value: 1.5975577796019256.
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 1.68374
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 1.68911
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 1.67884
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 1.68224
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 1.70084
# [I 2025-06-14 19:28:02,750] Trial 5 finished with value: 1.6869550426563742 and parameters: {'num_leaves': 131, 'learning_rate': 0.0035756793567883233, 'max_depth': 6, 'reg_alpha': 0.0003352532574306502, 'reg_lambda': 0.04127989591553768, 'feature_fraction': 0.7891048128108265, 'bagging_fraction': 0.9397669501941917, 'bagging_freq': 1, 'min_data_in_leaf': 169}. Best is trial 4 with value: 1.5975577796019256.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [391]	valid's rmse: 1.60774
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [311]	valid's rmse: 1.6162
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [294]	valid's rmse: 1.59652
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [364]	valid's rmse: 1.60015
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [455]	valid's rmse: 1.61964
# [I 2025-06-14 19:28:54,178] Trial 6 finished with value: 1.6080501780354592 and parameters: {'num_leaves': 30, 'learning_rate': 0.07511737052942642, 'max_depth': 12, 'reg_alpha': 0.0009040884568982261, 'reg_lambda': 5.889870175124454, 'feature_fraction': 0.6664289643882277, 'bagging_fraction': 0.5580546342887509, 'bagging_freq': 5, 'min_data_in_leaf': 200}. Best is trial 4 with value: 1.5975577796019256.
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 1.5978
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 1.60627
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [499]	valid's rmse: 1.58632
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 1.59368
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 1.61179
# [I 2025-06-14 19:30:56,662] Trial 7 finished with value: 1.599172398034146 and parameters: {'num_leaves': 149, 'learning_rate': 0.021584729121977998, 'max_depth': 12, 'reg_alpha': 7.376024827825465, 'reg_lambda': 0.0008077586571489891, 'feature_fraction': 0.6648231984664661, 'bagging_fraction': 0.8036760300859622, 'bagging_freq': 5, 'min_data_in_leaf': 204}. Best is trial 4 with value: 1.5975577796019256.
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 1.61116
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 1.61835
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 1.60104
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [499]	valid's rmse: 1.60356
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [498]	valid's rmse: 1.62623
# [I 2025-06-14 19:32:07,485] Trial 8 finished with value: 1.6120703046570306 and parameters: {'num_leaves': 107, 'learning_rate': 0.027521448316098446, 'max_depth': 10, 'reg_alpha': 0.004026360901338699, 'reg_lambda': 0.000305705563511273, 'feature_fraction': 0.9006505683344346, 'bagging_fraction': 0.4151335109209015, 'bagging_freq': 2, 'min_data_in_leaf': 432}. Best is trial 4 with value: 1.5975577796019256.
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 1.79751
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 1.79613
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 1.79699
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 1.79513
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 1.80683
# [I 2025-06-14 19:33:08,783] Trial 9 finished with value: 1.7985178664234538 and parameters: {'num_leaves': 26, 'learning_rate': 0.0024446594456802922, 'max_depth': 7, 'reg_alpha': 0.001499402648929466, 'reg_lambda': 0.006244650388242344, 'feature_fraction': 0.4870981102803031, 'bagging_fraction': 0.4813828127928418, 'bagging_freq': 1, 'min_data_in_leaf': 92}. Best is trial 4 with value: 1.5975577796019256.
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 1.61894
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 1.62701
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 1.60577
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 1.61362
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 1.63557
# [I 2025-06-14 19:34:19,068] Trial 10 finished with value: 1.6201831639713329 and parameters: {'num_leaves': 67, 'learning_rate': 0.019958650033540908, 'max_depth': 5, 'reg_alpha': 0.3235833597338905, 'reg_lambda': 0.3096361937688201, 'feature_fraction': 0.9529539423814751, 'bagging_fraction': 0.758504606317353, 'bagging_freq': 7, 'min_data_in_leaf': 347}. Best is trial 4 with value: 1.5975577796019256.
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 19:34:21,447] Trial 11 pruned. Trial was pruned at iteration 50.
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 19:34:23,690] Trial 12 pruned. Trial was pruned at iteration 50.
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [477]	valid's rmse: 1.60173
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [493]	valid's rmse: 1.60776
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [491]	valid's rmse: 1.58598
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [488]	valid's rmse: 1.59281
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [457]	valid's rmse: 1.61343
# [I 2025-06-14 19:36:02,454] Trial 13 finished with value: 1.6003411687424864 and parameters: {'num_leaves': 65, 'learning_rate': 0.04052941448401584, 'max_depth': 12, 'reg_alpha': 0.17424112645795228, 'reg_lambda': 0.3607222298392973, 'feature_fraction': 0.7655023821774583, 'bagging_fraction': 0.8570248648067327, 'bagging_freq': 6, 'min_data_in_leaf': 24}. Best is trial 4 with value: 1.5975577796019256.
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 19:36:04,317] Trial 14 pruned. Trial was pruned at iteration 50.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [181]	valid's rmse: 1.60322
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [228]	valid's rmse: 1.61348
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [140]	valid's rmse: 1.59246
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [149]	valid's rmse: 1.60132
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [169]	valid's rmse: 1.61913
# [I 2025-06-14 19:37:01,568] Trial 15 finished with value: 1.605924280857946 and parameters: {'num_leaves': 149, 'learning_rate': 0.09475105415437622, 'max_depth': 11, 'reg_alpha': 0.03352448787564095, 'reg_lambda': 0.07761277023593155, 'feature_fraction': 0.7232234756988024, 'bagging_fraction': 0.8718391173030449, 'bagging_freq': 3, 'min_data_in_leaf': 234}. Best is trial 4 with value: 1.5975577796019256.
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [488]	valid's rmse: 1.59892
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [495]	valid's rmse: 1.60387
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [499]	valid's rmse: 1.5866
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 1.59578
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [486]	valid's rmse: 1.61154
# [I 2025-06-14 19:39:09,053] Trial 16 finished with value: 1.5993432173044915 and parameters: {'num_leaves': 104, 'learning_rate': 0.03818029247511332, 'max_depth': 10, 'reg_alpha': 0.03881803717055303, 'reg_lambda': 1.7087530489429836, 'feature_fraction': 0.8624086565552432, 'bagging_fraction': 0.9987561539929737, 'bagging_freq': 5, 'min_data_in_leaf': 355}. Best is trial 4 with value: 1.5975577796019256.
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 19:39:12,849] Trial 17 pruned. Trial was pruned at iteration 50.
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 19:39:15,161] Trial 18 pruned. Trial was pruned at iteration 50.
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [496]	valid's rmse: 1.60005
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [487]	valid's rmse: 1.60769
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [487]	valid's rmse: 1.5888
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [495]	valid's rmse: 1.59483
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [496]	valid's rmse: 1.61185
# [I 2025-06-14 19:40:29,345] Trial 19 finished with value: 1.60064268149589 and parameters: {'num_leaves': 79, 'learning_rate': 0.047740649213774, 'max_depth': 8, 'reg_alpha': 0.07324898225688262, 'reg_lambda': 0.09504308102318162, 'feature_fraction': 0.5163158582220793, 'bagging_fraction': 0.7776349809846423, 'bagging_freq': 6, 'min_data_in_leaf': 291}. Best is trial 4 with value: 1.5975577796019256.
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 19:40:31,341] Trial 20 pruned. Trial was pruned at iteration 50.
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [490]	valid's rmse: 1.60154
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [490]	valid's rmse: 1.60517
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [473]	valid's rmse: 1.58834
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [488]	valid's rmse: 1.59702
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [493]	valid's rmse: 1.6155
# [I 2025-06-14 19:42:44,022] Trial 21 finished with value: 1.6015138923924 and parameters: {'num_leaves': 106, 'learning_rate': 0.039278950418040956, 'max_depth': 10, 'reg_alpha': 0.05987026004704816, 'reg_lambda': 2.9808172606637657, 'feature_fraction': 0.9985243825400447, 'bagging_fraction': 0.9915500873956528, 'bagging_freq': 5, 'min_data_in_leaf': 335}. Best is trial 4 with value: 1.5975577796019256.
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 19:42:47,015] Trial 22 pruned. Trial was pruned at iteration 50.
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 19:42:49,796] Trial 23 pruned. Trial was pruned at iteration 50.
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [492]	valid's rmse: 1.59963
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [499]	valid's rmse: 1.607
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 1.58737
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 1.59261
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 1.61232
# [I 2025-06-14 19:44:35,972] Trial 24 finished with value: 1.5997857616778401 and parameters: {'num_leaves': 137, 'learning_rate': 0.031149554311501872, 'max_depth': 9, 'reg_alpha': 2.3167807608061675, 'reg_lambda': 1.5465526401295069, 'feature_fraction': 0.6735213089463983, 'bagging_fraction': 0.8910971952842585, 'bagging_freq': 6, 'min_data_in_leaf': 316}. Best is trial 4 with value: 1.5975577796019256.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [443]	valid's rmse: 1.59766
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [405]	valid's rmse: 1.60484
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [427]	valid's rmse: 1.58918
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [469]	valid's rmse: 1.59725
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [408]	valid's rmse: 1.61505
# [I 2025-06-14 19:46:33,904] Trial 25 finished with value: 1.6007958981214372 and parameters: {'num_leaves': 75, 'learning_rate': 0.056258830252749054, 'max_depth': 10, 'reg_alpha': 0.11682028980621138, 'reg_lambda': 0.8370640814129413, 'feature_fraction': 0.8624674654692767, 'bagging_fraction': 0.9548753148978789, 'bagging_freq': 4, 'min_data_in_leaf': 245}. Best is trial 4 with value: 1.5975577796019256.
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 19:46:36,358] Trial 26 pruned. Trial was pruned at iteration 50.
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 19:46:38,758] Trial 27 pruned. Trial was pruned at iteration 50.
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 1.59762
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [499]	valid's rmse: 1.60492
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [485]	valid's rmse: 1.58904
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [431]	valid's rmse: 1.59502
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [493]	valid's rmse: 1.60937
# [I 2025-06-14 19:48:41,313] Trial 28 finished with value: 1.5991951070036934 and parameters: {'num_leaves': 119, 'learning_rate': 0.038579318757018116, 'max_depth': 11, 'reg_alpha': 0.0038180257487353446, 'reg_lambda': 0.0010322354517518094, 'feature_fraction': 0.8098675759008898, 'bagging_fraction': 0.8084177201486914, 'bagging_freq': 6, 'min_data_in_leaf': 262}. Best is trial 4 with value: 1.5975577796019256.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [180]	valid's rmse: 1.60004
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [295]	valid's rmse: 1.61209
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [265]	valid's rmse: 1.59532
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [199]	valid's rmse: 1.60009
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [305]	valid's rmse: 1.61301
# [I 2025-06-14 19:50:05,989] Trial 29 finished with value: 1.604109874190734 and parameters: {'num_leaves': 121, 'learning_rate': 0.06496865251490637, 'max_depth': 12, 'reg_alpha': 0.002581031060139988, 'reg_lambda': 0.003785900428788777, 'feature_fraction': 0.8166043950892728, 'bagging_fraction': 0.803615808463058, 'bagging_freq': 7, 'min_data_in_leaf': 114}. Best is trial 4 with value: 1.5975577796019256.
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 19:50:08,470] Trial 30 pruned. Trial was pruned at iteration 50.
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 19:50:13,848] Trial 31 pruned. Trial was pruned at iteration 58.
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 19:50:19,535] Trial 32 pruned. Trial was pruned at iteration 126.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [401]	valid's rmse: 1.59911
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [462]	valid's rmse: 1.60529
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [447]	valid's rmse: 1.58733
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [340]	valid's rmse: 1.59157
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 1.61176
# [I 2025-06-14 19:51:58,652] Trial 33 finished with value: 1.5990110386652514 and parameters: {'num_leaves': 88, 'learning_rate': 0.05207278914051467, 'max_depth': 12, 'reg_alpha': 0.040627892122609595, 'reg_lambda': 0.0005528742723710662, 'feature_fraction': 0.5598692738524826, 'bagging_fraction': 0.9099388398607651, 'bagging_freq': 5, 'min_data_in_leaf': 313}. Best is trial 4 with value: 1.5975577796019256.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [252]	valid's rmse: 1.60517
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [252]	valid's rmse: 1.60952
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [189]	valid's rmse: 1.59144
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [215]	valid's rmse: 1.599
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [300]	valid's rmse: 1.61369
# [I 2025-06-14 19:52:58,139] Trial 34 finished with value: 1.6037657463872752 and parameters: {'num_leaves': 89, 'learning_rate': 0.08223701696803562, 'max_depth': 12, 'reg_alpha': 0.0203009911790602, 'reg_lambda': 0.0005090107566297399, 'feature_fraction': 0.5559538306793352, 'bagging_fraction': 0.9025356165108789, 'bagging_freq': 7, 'min_data_in_leaf': 312}. Best is trial 4 with value: 1.5975577796019256.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [399]	valid's rmse: 1.60001
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [346]	valid's rmse: 1.60458
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [412]	valid's rmse: 1.58726
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [380]	valid's rmse: 1.59187
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [454]	valid's rmse: 1.61206
# [I 2025-06-14 19:54:27,987] Trial 35 finished with value: 1.5991537385039654 and parameters: {'num_leaves': 117, 'learning_rate': 0.05173000712148957, 'max_depth': 12, 'reg_alpha': 0.002125173633057823, 'reg_lambda': 0.0002986559059477174, 'feature_fraction': 0.5167999091937255, 'bagging_fraction': 0.8055971012792267, 'bagging_freq': 5, 'min_data_in_leaf': 259}. Best is trial 4 with value: 1.5975577796019256.
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [463]	valid's rmse: 1.59364
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [497]	valid's rmse: 1.60187
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [498]	valid's rmse: 1.58345
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [495]	valid's rmse: 1.59106
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [417]	valid's rmse: 1.60835
# [I 2025-06-14 19:56:00,799] Trial 36 finished with value: 1.5956745116025683 and parameters: {'num_leaves': 82, 'learning_rate': 0.05248505795522122, 'max_depth': 12, 'reg_alpha': 9.038224007343509, 'reg_lambda': 0.00025951838526879097, 'feature_fraction': 0.4584324526830628, 'bagging_fraction': 0.9315558788132813, 'bagging_freq': 4, 'min_data_in_leaf': 140}. Best is trial 36 with value: 1.5956745116025683.
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [490]	valid's rmse: 1.59701
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [486]	valid's rmse: 1.60349
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [243]	valid's rmse: 1.58998
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [281]	valid's rmse: 1.59607
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [436]	valid's rmse: 1.61072
# [I 2025-06-14 19:57:15,901] Trial 37 finished with value: 1.5994550900707563 and parameters: {'num_leaves': 82, 'learning_rate': 0.05860601236899683, 'max_depth': 12, 'reg_alpha': 0.00013622477796905208, 'reg_lambda': 0.00029908425816941605, 'feature_fraction': 0.4070997533127785, 'bagging_fraction': 0.9577739615899585, 'bagging_freq': 4, 'min_data_in_leaf': 137}. Best is trial 36 with value: 1.5956745116025683.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [151]	valid's rmse: 1.6097
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 19:57:29,262] Trial 38 pruned. Trial was pruned at iteration 210.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [395]	valid's rmse: 1.60039
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [496]	valid's rmse: 1.60359
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [490]	valid's rmse: 1.58413
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [386]	valid's rmse: 1.59292
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 1.6097
# [I 2025-06-14 19:58:44,972] Trial 39 finished with value: 1.59814562175724 and parameters: {'num_leaves': 51, 'learning_rate': 0.05192381139448494, 'max_depth': 11, 'reg_alpha': 0.001560423964364906, 'reg_lambda': 0.030802127131186085, 'feature_fraction': 0.4635016453271848, 'bagging_fraction': 0.9354091951331163, 'bagging_freq': 2, 'min_data_in_leaf': 181}. Best is trial 36 with value: 1.5956745116025683.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [329]	valid's rmse: 1.60122
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 19:59:11,545] Trial 40 pruned. Trial was pruned at iteration 417.
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [482]	valid's rmse: 1.59999
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [490]	valid's rmse: 1.60469
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [337]	valid's rmse: 1.59209
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [472]	valid's rmse: 1.59374
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 1.60978
# [I 2025-06-14 20:00:23,820] Trial 41 finished with value: 1.6000575794504583 and parameters: {'num_leaves': 42, 'learning_rate': 0.05331931081354232, 'max_depth': 12, 'reg_alpha': 0.0018625776217993323, 'reg_lambda': 0.0005051889010196297, 'feature_fraction': 0.511124191223167, 'bagging_fraction': 0.8720417466841796, 'bagging_freq': 2, 'min_data_in_leaf': 153}. Best is trial 36 with value: 1.5956745116025683.
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 20:00:25,962] Trial 42 pruned. Trial was pruned at iteration 50.
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 20:00:33,407] Trial 43 pruned. Trial was pruned at iteration 214.
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 20:00:35,621] Trial 44 pruned. Trial was pruned at iteration 50.
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [488]	valid's rmse: 1.5963
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 1.60425
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [499]	valid's rmse: 1.58493
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [490]	valid's rmse: 1.59064
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 1.60954
# [I 2025-06-14 20:02:06,492] Trial 45 finished with value: 1.5971314047219773 and parameters: {'num_leaves': 64, 'learning_rate': 0.04724674674597503, 'max_depth': 12, 'reg_alpha': 0.002636562086210733, 'reg_lambda': 0.005532923864754977, 'feature_fraction': 0.5765193484427145, 'bagging_fraction': 0.9231497803869876, 'bagging_freq': 4, 'min_data_in_leaf': 79}. Best is trial 36 with value: 1.5956745116025683.
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 20:02:11,083] Trial 46 pruned. Trial was pruned at iteration 50.
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 20:02:19,749] Trial 47 pruned. Trial was pruned at iteration 324.
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 20:02:24,721] Trial 48 pruned. Trial was pruned at iteration 50.
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 20:02:30,706] Trial 49 pruned. Trial was pruned at iteration 202.
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 20:02:32,901] Trial 50 pruned. Trial was pruned at iteration 50.
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 20:02:36,001] Trial 51 pruned. Trial was pruned at iteration 50.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [372]	valid's rmse: 1.6007
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 20:03:06,695] Trial 52 pruned. Trial was pruned at iteration 435.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [283]	valid's rmse: 1.60256
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 20:03:25,244] Trial 53 pruned. Trial was pruned at iteration 371.
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [497]	valid's rmse: 1.59657
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [487]	valid's rmse: 1.60469
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [392]	valid's rmse: 1.5879
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [363]	valid's rmse: 1.59173
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 1.60833
# [I 2025-06-14 20:05:02,375] Trial 54 finished with value: 1.5978429833936658 and parameters: {'num_leaves': 70, 'learning_rate': 0.05083379593065183, 'max_depth': 12, 'reg_alpha': 0.0005060752445315917, 'reg_lambda': 0.0001492296662541845, 'feature_fraction': 0.584403112764412, 'bagging_fraction': 0.9126258796893131, 'bagging_freq': 5, 'min_data_in_leaf': 176}. Best is trial 36 with value: 1.5956745116025683.
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 20:05:04,460] Trial 55 pruned. Trial was pruned at iteration 50.
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 20:05:06,980] Trial 56 pruned. Trial was pruned at iteration 50.
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 20:05:09,066] Trial 57 pruned. Trial was pruned at iteration 50.
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 20:05:14,162] Trial 58 pruned. Trial was pruned at iteration 69.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [223]	valid's rmse: 1.60231
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [300]	valid's rmse: 1.60691
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [344]	valid's rmse: 1.5921
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [295]	valid's rmse: 1.59836
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [250]	valid's rmse: 1.61287
# [I 2025-06-14 20:06:28,530] Trial 59 finished with value: 1.6025110427054823 and parameters: {'num_leaves': 74, 'learning_rate': 0.07083172737376636, 'max_depth': 11, 'reg_alpha': 0.011405558474550104, 'reg_lambda': 0.03454744343270893, 'feature_fraction': 0.6950867849052776, 'bagging_fraction': 0.8887751446482318, 'bagging_freq': 4, 'min_data_in_leaf': 215}. Best is trial 36 with value: 1.5956745116025683.
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 20:06:30,661] Trial 60 pruned. Trial was pruned at iteration 50.
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 20:06:32,774] Trial 61 pruned. Trial was pruned at iteration 50.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [415]	valid's rmse: 1.59912
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [423]	valid's rmse: 1.60407
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [325]	valid's rmse: 1.58955
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [467]	valid's rmse: 1.59193
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [386]	valid's rmse: 1.61399
# [I 2025-06-14 20:07:45,593] Trial 62 finished with value: 1.5997330741525615 and parameters: {'num_leaves': 50, 'learning_rate': 0.054814307760535516, 'max_depth': 12, 'reg_alpha': 0.0005985405279546778, 'reg_lambda': 0.00028514353468055994, 'feature_fraction': 0.5318042645381927, 'bagging_fraction': 0.8548577870576125, 'bagging_freq': 4, 'min_data_in_leaf': 284}. Best is trial 36 with value: 1.5956745116025683.
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 20:07:49,463] Trial 63 pruned. Trial was pruned at iteration 50.
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 20:07:51,775] Trial 64 pruned. Trial was pruned at iteration 50.
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 20:08:03,840] Trial 65 pruned. Trial was pruned at iteration 350.
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 20:08:05,937] Trial 66 pruned. Trial was pruned at iteration 50.
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 20:08:08,209] Trial 67 pruned. Trial was pruned at iteration 50.
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 20:08:10,608] Trial 68 pruned. Trial was pruned at iteration 50.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [177]	valid's rmse: 1.60386
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 20:08:33,060] Trial 69 pruned. Trial was pruned at iteration 340.
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 20:08:35,048] Trial 70 pruned. Trial was pruned at iteration 50.
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 20:08:37,313] Trial 71 pruned. Trial was pruned at iteration 50.
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 20:08:40,281] Trial 72 pruned. Trial was pruned at iteration 50.
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 20:09:03,142] Trial 73 pruned. Trial was pruned at iteration 435.
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 20:09:05,792] Trial 74 pruned. Trial was pruned at iteration 50.
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 20:09:08,514] Trial 75 pruned. Trial was pruned at iteration 50.
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 20:09:16,232] Trial 76 pruned. Trial was pruned at iteration 170.
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 20:09:18,803] Trial 77 pruned. Trial was pruned at iteration 50.
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 20:09:21,219] Trial 78 pruned. Trial was pruned at iteration 50.
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [461]	valid's rmse: 1.59856
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [355]	valid's rmse: 1.60615
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [383]	valid's rmse: 1.58755
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [389]	valid's rmse: 1.5935
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [327]	valid's rmse: 1.61305
# [I 2025-06-14 20:10:34,628] Trial 79 finished with value: 1.599762057220778 and parameters: {'num_leaves': 133, 'learning_rate': 0.049828128401109215, 'max_depth': 12, 'reg_alpha': 0.001836571641492382, 'reg_lambda': 0.20296245498839768, 'feature_fraction': 0.5027001172585251, 'bagging_fraction': 0.7305757500360908, 'bagging_freq': 1, 'min_data_in_leaf': 237}. Best is trial 36 with value: 1.5956745116025683.
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 20:10:39,334] Trial 80 pruned. Trial was pruned at iteration 50.
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 20:10:41,179] Trial 81 pruned. Trial was pruned at iteration 50.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [281]	valid's rmse: 1.60137
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 20:11:12,039] Trial 82 pruned. Trial was pruned at iteration 365.
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [457]	valid's rmse: 1.59981
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 1.60576
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [431]	valid's rmse: 1.59158
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [482]	valid's rmse: 1.59711
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [499]	valid's rmse: 1.61258
# [I 2025-06-14 20:12:47,298] Trial 83 finished with value: 1.6013672050649626 and parameters: {'num_leaves': 46, 'learning_rate': 0.06029787390207349, 'max_depth': 12, 'reg_alpha': 0.0036099940539470114, 'reg_lambda': 0.0011528953139149408, 'feature_fraction': 0.8153472005024978, 'bagging_fraction': 0.8965093266026902, 'bagging_freq': 6, 'min_data_in_leaf': 215}. Best is trial 36 with value: 1.5956745116025683.
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 20:12:50,223] Trial 84 pruned. Trial was pruned at iteration 50.
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 20:12:52,310] Trial 85 pruned. Trial was pruned at iteration 50.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [295]	valid's rmse: 1.60183
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 20:13:33,109] Trial 86 pruned. Trial was pruned at iteration 355.
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 20:13:35,562] Trial 87 pruned. Trial was pruned at iteration 50.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [185]	valid's rmse: 1.60271
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 20:14:02,823] Trial 88 pruned. Trial was pruned at iteration 350.
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 20:14:08,567] Trial 89 pruned. Trial was pruned at iteration 50.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [412]	valid's rmse: 1.59781
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [389]	valid's rmse: 1.60577
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [431]	valid's rmse: 1.58676
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [499]	valid's rmse: 1.59578
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [494]	valid's rmse: 1.61069
# [I 2025-06-14 20:15:50,039] Trial 90 finished with value: 1.599363881376782 and parameters: {'num_leaves': 63, 'learning_rate': 0.0473468847652632, 'max_depth': 11, 'reg_alpha': 0.0026771357233211063, 'reg_lambda': 0.0030704853902254166, 'feature_fraction': 0.7879463035980054, 'bagging_fraction': 0.95711686358863, 'bagging_freq': 7, 'min_data_in_leaf': 127}. Best is trial 36 with value: 1.5956745116025683.
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 20:15:53,041] Trial 91 pruned. Trial was pruned at iteration 50.
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 20:16:02,409] Trial 92 pruned. Trial was pruned at iteration 177.
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 20:16:20,621] Trial 93 pruned. Trial was pruned at iteration 368.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [403]	valid's rmse: 1.59989
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [495]	valid's rmse: 1.60306
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [499]	valid's rmse: 1.5866
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [458]	valid's rmse: 1.594
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [499]	valid's rmse: 1.61012
# [I 2025-06-14 20:18:31,250] Trial 94 finished with value: 1.5987333228857323 and parameters: {'num_leaves': 90, 'learning_rate': 0.04488805814934439, 'max_depth': 12, 'reg_alpha': 0.03773279625970953, 'reg_lambda': 6.005647466337726, 'feature_fraction': 0.8281794057115707, 'bagging_fraction': 0.985691815878895, 'bagging_freq': 4, 'min_data_in_leaf': 355}. Best is trial 36 with value: 1.5956745116025683.
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 20:18:36,864] Trial 95 pruned. Trial was pruned at iteration 54.
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 20:18:39,157] Trial 96 pruned. Trial was pruned at iteration 50.
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [495]	valid's rmse: 1.597
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 1.60396
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [490]	valid's rmse: 1.58364
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [457]	valid's rmse: 1.59353
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [487]	valid's rmse: 1.61146
# [I 2025-06-14 20:20:07,536] Trial 97 finished with value: 1.5979202437929394 and parameters: {'num_leaves': 69, 'learning_rate': 0.053786003372567705, 'max_depth': 12, 'reg_alpha': 0.0002869008462852845, 'reg_lambda': 4.01841669925096, 'feature_fraction': 0.440849793774667, 'bagging_fraction': 0.9825267656216558, 'bagging_freq': 4, 'min_data_in_leaf': 408}. Best is trial 36 with value: 1.5956745116025683.
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 20:20:19,771] Trial 98 pruned. Trial was pruned at iteration 355.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [397]	valid's rmse: 1.59942
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [498]	valid's rmse: 1.60259
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [368]	valid's rmse: 1.58955
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [470]	valid's rmse: 1.59313
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [476]	valid's rmse: 1.60947
# [I 2025-06-14 20:21:44,213] Trial 99 finished with value: 1.598830700536797 and parameters: {'num_leaves': 78, 'learning_rate': 0.06659545680263726, 'max_depth': 12, 'reg_alpha': 0.00014655439197323243, 'reg_lambda': 5.830160230931898, 'feature_fraction': 0.409013558438587, 'bagging_fraction': 0.9912658109046742, 'bagging_freq': 4, 'min_data_in_leaf': 400}. Best is trial 36 with value: 1.5956745116025683.

# %%
model, test_rmse= training(X, y,
    params_json_path="exp_GDP_poor_best_params.json",
    save_model_path='exp_GDP_poor_model.txt',
    save_log_filename="exp_GDP_poor_log.csv")
# Out:
# Training until validation scores don't improve for 50 rounds
# [50]	valid's rmse: 1.67744	valid's l2: 2.8138
# [100]	valid's rmse: 1.64085	valid's l2: 2.6924
# [150]	valid's rmse: 1.63234	valid's l2: 2.66455
# [200]	valid's rmse: 1.62838	valid's l2: 2.65161
# [250]	valid's rmse: 1.62536	valid's l2: 2.64179
# [300]	valid's rmse: 1.62424	valid's l2: 2.63815
# [350]	valid's rmse: 1.6224	valid's l2: 2.63218
# [400]	valid's rmse: 1.62173	valid's l2: 2.63
# Early stopping, best iteration is:
# [387]	valid's rmse: 1.62134	valid's l2: 2.62874

# %%
# Compute the standard deviation of y
std_y = y.std()
print(f"The standard deviation of y is: {std_y}")
# Out:
# The standard deviation of y is: 2.183899857048508

# %%
evaluation(model,
    X.sample(10000),
    name = "exp_GDP_poor_results",
    max_display=30)
