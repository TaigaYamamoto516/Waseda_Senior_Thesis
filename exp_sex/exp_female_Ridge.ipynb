# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import os
os.chdir('/content/drive/MyDrive/Senior_Thesis_Waseda/exp_sex')

# %%
# %run ../Ridge.ipynb

# %%
df = pd.read_csv('/content/drive/MyDrive/Senior_Thesis_Waseda/happiness_data.csv')
df.head()
# Out:
#    happiness B_COUNTRY_ALPHA  D_INTERVIEW  G_TOWNSIZE  GDP group  \
# 0   7.333333             CYP    196070011         6.0          1
# 1   8.000000             CYP    196070036         6.0          1
# 2   8.000000             CYP    196070039         6.0          1
# 3   5.333333             CYP    196070040         6.0          1
# 4   4.000000             CYP    196070053         6.0          1
#
#    H_SETTLEMENT      Cl_1      Cl_2      Cl_3     Cl_4  ...     Cl_67  \
# 0           4.0  0.936297 -0.623011 -1.308899 -0.65273  ... -1.675059
# 1           4.0  0.936297 -0.623011  0.764001 -0.65273  ...  0.580208
# 2           4.0  0.936297 -0.623011  0.764001 -0.65273  ...  0.574066
# 3           4.0  0.936297 -0.623011  0.764001 -0.65273  ... -0.009851
# 4           4.0  0.936297 -0.623011  0.764001 -0.65273  ...  0.507466
#
#       Cl_68     Cl_69     Cl_70     Cl_71     Cl_72  Cl_73  Cl_74  Cl_75  \
# 0  0.345000  0.976462 -1.848202 -1.456204  0.884878      2      1      6
# 1 -0.332603  0.976462 -1.218074 -0.272563  0.884878      1      1      8
# 2  0.146194 -0.200705 -0.266231  0.323946  0.268851      1      1      0
# 3  0.143230  0.976462 -0.742153 -0.272563  0.884878      1      1      8
# 4 -0.300418  0.386842  0.839819  0.915767  0.268851      2      5      8
#
#    Cl_76
# 0      3
# 1      3
# 2      3
# 3      3
# 4      3
#
# [5 rows x 82 columns]

# %%
income = pd.read_csv('/content/drive/MyDrive/Senior_Thesis_Waseda/happiness_data_pre_cluster.csv')
income = income.loc[:, ['D_INTERVIEW','Q260']]
income.head()
# Out:
#    D_INTERVIEW  Q260
# 0    196070011     1
# 1    196070036     2
# 2    196070039     2
# 3    196070040     2
# 4    196070053     2

# %%
import matplotlib.pyplot as plt

plt.hist(income['Q260'])
plt.xlabel('Q260')
plt.ylabel('Frequency')
plt.title('Histogram of Q260')
plt.show()

# %%
df_merged = pd.merge(income, df, on='D_INTERVIEW')
df_merged.head()
# Out:
#    D_INTERVIEW  Q260  happiness B_COUNTRY_ALPHA  G_TOWNSIZE  GDP group  \
# 0    196070011     1   7.333333             CYP         6.0          1
# 1    196070036     2   8.000000             CYP         6.0          1
# 2    196070039     2   8.000000             CYP         6.0          1
# 3    196070040     2   5.333333             CYP         6.0          1
# 4    196070053     2   4.000000             CYP         6.0          1
#
#    H_SETTLEMENT      Cl_1      Cl_2      Cl_3  ...     Cl_67     Cl_68  \
# 0           4.0  0.936297 -0.623011 -1.308899  ... -1.675059  0.345000
# 1           4.0  0.936297 -0.623011  0.764001  ...  0.580208 -0.332603
# 2           4.0  0.936297 -0.623011  0.764001  ...  0.574066  0.146194
# 3           4.0  0.936297 -0.623011  0.764001  ... -0.009851  0.143230
# 4           4.0  0.936297 -0.623011  0.764001  ...  0.507466 -0.300418
#
#       Cl_69     Cl_70     Cl_71     Cl_72  Cl_73  Cl_74  Cl_75  Cl_76
# 0  0.976462 -1.848202 -1.456204  0.884878      2      1      6      3
# 1  0.976462 -1.218074 -0.272563  0.884878      1      1      8      3
# 2 -0.200705 -0.266231  0.323946  0.268851      1      1      0      3
# 3  0.976462 -0.742153 -0.272563  0.884878      1      1      8      3
# 4  0.386842  0.839819  0.915767  0.268851      2      5      8      3
#
# [5 rows x 83 columns]

# %%
df_merged = df_merged[df_merged['Q260'] == 2]
df_merged.head()
# Out:
#    D_INTERVIEW  Q260  happiness B_COUNTRY_ALPHA  G_TOWNSIZE  GDP group  \
# 1    196070036     2   8.000000             CYP         6.0          1
# 2    196070039     2   8.000000             CYP         6.0          1
# 3    196070040     2   5.333333             CYP         6.0          1
# 4    196070053     2   4.000000             CYP         6.0          1
# 7    196070069     2   8.000000             CYP         6.0          1
#
#    H_SETTLEMENT      Cl_1      Cl_2      Cl_3  ...     Cl_67     Cl_68  \
# 1           4.0  0.936297 -0.623011  0.764001  ...  0.580208 -0.332603
# 2           4.0  0.936297 -0.623011  0.764001  ...  0.574066  0.146194
# 3           4.0  0.936297 -0.623011  0.764001  ... -0.009851  0.143230
# 4           4.0  0.936297 -0.623011  0.764001  ...  0.507466 -0.300418
# 7           4.0  0.936297  1.605107  0.764001  ... -0.335459 -0.174605
#
#       Cl_69     Cl_70     Cl_71     Cl_72  Cl_73  Cl_74  Cl_75  Cl_76
# 1  0.976462 -1.218074 -0.272563  0.884878      1      1      8      3
# 2 -0.200705 -0.266231  0.323946  0.268851      1      1      0      3
# 3  0.976462 -0.742153 -0.272563  0.884878      1      1      8      3
# 4  0.386842  0.839819  0.915767  0.268851      2      5      8      3
# 7  0.976462 -1.218074 -1.456204  0.884878      1      1      5      3
#
# [5 rows x 83 columns]

# %%
X = df_merged.loc[:, 'Cl_1':]
y = df_merged['happiness']

# %%
model, best_alpha, coeffs, perm_imp = Ridge(X,y)

# %%
save_data(perm_imp, coeffs, test_name='exp_female')
