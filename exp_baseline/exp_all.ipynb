# %%
# !pip install lightgbm optuna
# !pip install optuna-integration[lightgbm]
import shap
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import json
import lightgbm as lgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import KFold
import optuna
from optuna.integration import LightGBMPruningCallback
import sys
# Out:
# Requirement already satisfied: lightgbm in /usr/local/lib/python3.11/dist-packages (4.5.0)
# Collecting optuna
#   Downloading optuna-4.3.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from lightgbm) (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from lightgbm) (1.15.3)
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.16.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.9.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.41)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from optuna) (6.0.2)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic>=1.5.0->optuna) (1.1.3)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.11/dist-packages (from alembic>=1.5.0->optuna) (4.14.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.2.2)
# Downloading optuna-4.3.0-py3-none-any.whl (386 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 386.6/386.6 kB 7.7 MB/s eta 0:00:00
# Downloading alembic-1.16.1-py3-none-any.whl (242 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.5/242.5 kB 17.8 MB/s eta 0:00:00
# Downloading colorlog-6.9.0-py3-none-any.whl (11 kB)
# Installing collected packages: colorlog, alembic, optuna
# Successfully installed alembic-1.16.1 colorlog-6.9.0 optuna-4.3.0
# Collecting optuna-integration[lightgbm]
#   Downloading optuna_integration-4.3.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: optuna in /usr/local/lib/python3.11/dist-packages (from optuna-integration[lightgbm]) (4.3.0)
# Requirement already satisfied: lightgbm in /usr/local/lib/python3.11/dist-packages (from optuna-integration[lightgbm]) (4.5.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from optuna-integration[lightgbm]) (1.6.1)
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from lightgbm->optuna-integration[lightgbm]) (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from lightgbm->optuna-integration[lightgbm]) (1.15.3)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from optuna->optuna-integration[lightgbm]) (1.16.1)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.11/dist-packages (from optuna->optuna-integration[lightgbm]) (6.9.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from optuna->optuna-integration[lightgbm]) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from optuna->optuna-integration[lightgbm]) (2.0.41)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from optuna->optuna-integration[lightgbm]) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from optuna->optuna-integration[lightgbm]) (6.0.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->optuna-integration[lightgbm]) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->optuna-integration[lightgbm]) (3.6.0)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic>=1.5.0->optuna->optuna-integration[lightgbm]) (1.1.3)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.11/dist-packages (from alembic>=1.5.0->optuna->optuna-integration[lightgbm]) (4.14.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.2->optuna->optuna-integration[lightgbm]) (3.2.2)
# Downloading optuna_integration-4.3.0-py3-none-any.whl (98 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.5/98.5 kB 2.7 MB/s eta 0:00:00
# Installing collected packages: optuna-integration
# Successfully installed optuna-integration-4.3.0

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
import os
os.chdir('/content/drive/MyDrive/Senior_Thesis_Waseda/exp_all')

# %%
# %run ../evaluation.ipynb
# %run ../training.ipynb
# %run ../parameter_optimization.ipynb
# Out:
# Requirement already satisfied: lightgbm in /usr/local/lib/python3.11/dist-packages (4.5.0)
# Requirement already satisfied: optuna in /usr/local/lib/python3.11/dist-packages (4.3.0)
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from lightgbm) (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from lightgbm) (1.15.3)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (1.16.1)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.11/dist-packages (from optuna) (6.9.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.41)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from optuna) (6.0.2)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic>=1.5.0->optuna) (1.1.3)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.11/dist-packages (from alembic>=1.5.0->optuna) (4.14.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.2.2)
# Requirement already satisfied: optuna-integration[lightgbm] in /usr/local/lib/python3.11/dist-packages (4.3.0)
# Requirement already satisfied: optuna in /usr/local/lib/python3.11/dist-packages (from optuna-integration[lightgbm]) (4.3.0)
# Requirement already satisfied: lightgbm in /usr/local/lib/python3.11/dist-packages (from optuna-integration[lightgbm]) (4.5.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from optuna-integration[lightgbm]) (1.6.1)
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from lightgbm->optuna-integration[lightgbm]) (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from lightgbm->optuna-integration[lightgbm]) (1.15.3)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from optuna->optuna-integration[lightgbm]) (1.16.1)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.11/dist-packages (from optuna->optuna-integration[lightgbm]) (6.9.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from optuna->optuna-integration[lightgbm]) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from optuna->optuna-integration[lightgbm]) (2.0.41)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from optuna->optuna-integration[lightgbm]) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from optuna->optuna-integration[lightgbm]) (6.0.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->optuna-integration[lightgbm]) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->optuna-integration[lightgbm]) (3.6.0)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic>=1.5.0->optuna->optuna-integration[lightgbm]) (1.1.3)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.11/dist-packages (from alembic>=1.5.0->optuna->optuna-integration[lightgbm]) (4.14.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.2->optuna->optuna-integration[lightgbm]) (3.2.2)

# %%
df = pd.read_csv('/content/drive/MyDrive/Senior_Thesis_Waseda/happiness_data.csv')
df.head()
# Out:
#    happiness B_COUNTRY_ALPHA  D_INTERVIEW  G_TOWNSIZE  GDP group  \
# 0   7.333333             CYP    196070011         6.0          1
# 1   8.000000             CYP    196070036         6.0          1
# 2   8.000000             CYP    196070039         6.0          1
# 3   5.333333             CYP    196070040         6.0          1
# 4   4.000000             CYP    196070053         6.0          1
#
#    H_SETTLEMENT      Cl_1      Cl_2      Cl_3     Cl_4  ...     Cl_67  \
# 0           4.0  0.936297 -0.623011 -1.308899 -0.65273  ... -1.675059
# 1           4.0  0.936297 -0.623011  0.764001 -0.65273  ...  0.580208
# 2           4.0  0.936297 -0.623011  0.764001 -0.65273  ...  0.574066
# 3           4.0  0.936297 -0.623011  0.764001 -0.65273  ... -0.009851
# 4           4.0  0.936297 -0.623011  0.764001 -0.65273  ...  0.507466
#
#       Cl_68     Cl_69     Cl_70     Cl_71     Cl_72  Cl_73  Cl_74  Cl_75  \
# 0  0.345000  0.976462 -1.848202 -1.456204  0.884878      2      1      6
# 1 -0.332603  0.976462 -1.218074 -0.272563  0.884878      1      1      8
# 2  0.146194 -0.200705 -0.266231  0.323946  0.268851      1      1      0
# 3  0.143230  0.976462 -0.742153 -0.272563  0.884878      1      1      8
# 4 -0.300418  0.386842  0.839819  0.915767  0.268851      2      5      8
#
#    Cl_76
# 0      3
# 1      3
# 2      3
# 3      3
# 4      3
#
# [5 rows x 82 columns]

# %%
categorical = ['Cl_73', 'Cl_74', 'Cl_75', 'Cl_76']

for col in categorical:
    if col in df.columns:
        df[col] = df[col].astype('category')

# %%
X = df.loc[:, 'Cl_1':]
y = df['happiness']

# %%
parameter_optimization(X, y,
    save_path="exp_all_best_params.json")
# Out:
# [I 2025-06-14 17:21:25,320] A new study created in memory with name: lgbm_regression_opt
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [498]	valid's rmse: 1.49377
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [484]	valid's rmse: 1.49046
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 1.50553
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [485]	valid's rmse: 1.48268
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [499]	valid's rmse: 1.48443
# [I 2025-06-14 17:22:31,681] Trial 0 finished with value: 1.4913726798159461 and parameters: {'num_leaves': 37, 'learning_rate': 0.059662768998574464, 'max_depth': 12, 'reg_alpha': 0.01689821456403644, 'reg_lambda': 0.008733286960935062, 'feature_fraction': 0.5545578611806954, 'bagging_fraction': 0.7944205512826226, 'bagging_freq': 4, 'min_data_in_leaf': 483}. Best is trial 0 with value: 1.4913726798159461.
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 1.52379
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 1.52691
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 1.53963
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 1.52003
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 1.51914
# [I 2025-06-14 17:23:34,436] Trial 1 finished with value: 1.5258999312528458 and parameters: {'num_leaves': 124, 'learning_rate': 0.008135993077935482, 'max_depth': 11, 'reg_alpha': 0.00016165526881359486, 'reg_lambda': 0.7035409156988579, 'feature_fraction': 0.4019026700531766, 'bagging_fraction': 0.5756856352296862, 'bagging_freq': 5, 'min_data_in_leaf': 459}. Best is trial 0 with value: 1.4913726798159461.
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 1.62929
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 1.63876
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 1.64898
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 1.63289
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 1.62394
# [I 2025-06-14 17:24:55,560] Trial 2 finished with value: 1.6347751091180662 and parameters: {'num_leaves': 59, 'learning_rate': 0.0031419355583659327, 'max_depth': 9, 'reg_alpha': 8.662924996503568, 'reg_lambda': 0.02194583099502228, 'feature_fraction': 0.47397242771581266, 'bagging_fraction': 0.9496188320394634, 'bagging_freq': 7, 'min_data_in_leaf': 153}. Best is trial 0 with value: 1.4913726798159461.
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 1.6985
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 1.70893
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 1.71557
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 1.70161
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 1.69292
# [I 2025-06-14 17:25:44,561] Trial 3 finished with value: 1.7035053840426273 and parameters: {'num_leaves': 88, 'learning_rate': 0.0020393416894354194, 'max_depth': 3, 'reg_alpha': 0.004180382606157517, 'reg_lambda': 9.005175761589022, 'feature_fraction': 0.7078847726835956, 'bagging_fraction': 0.9258973847512997, 'bagging_freq': 1, 'min_data_in_leaf': 156}. Best is trial 0 with value: 1.4913726798159461.
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 1.49072
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 1.48769
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 1.50129
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 1.47829
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 1.48125
# [I 2025-06-14 17:27:30,662] Trial 4 finished with value: 1.487852109768669 and parameters: {'num_leaves': 81, 'learning_rate': 0.03338461566965746, 'max_depth': 12, 'reg_alpha': 0.009228237972087388, 'reg_lambda': 4.420164028591646, 'feature_fraction': 0.6997672062599631, 'bagging_fraction': 0.8812298141809676, 'bagging_freq': 7, 'min_data_in_leaf': 251}. Best is trial 4 with value: 1.487852109768669.
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 1.57216
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 1.57838
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 1.58818
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 1.57047
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 1.56859
# [I 2025-06-14 17:29:02,180] Trial 5 finished with value: 1.5755562593888668 and parameters: {'num_leaves': 131, 'learning_rate': 0.0035756793567883233, 'max_depth': 6, 'reg_alpha': 0.0003352532574306502, 'reg_lambda': 0.04127989591553768, 'feature_fraction': 0.7891048128108265, 'bagging_fraction': 0.9397669501941917, 'bagging_freq': 1, 'min_data_in_leaf': 169}. Best is trial 4 with value: 1.487852109768669.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [444]	valid's rmse: 1.49841
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [444]	valid's rmse: 1.49403
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [478]	valid's rmse: 1.50756
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [453]	valid's rmse: 1.48932
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [406]	valid's rmse: 1.49355
# [I 2025-06-14 17:29:50,739] Trial 6 finished with value: 1.496572048146015 and parameters: {'num_leaves': 30, 'learning_rate': 0.07511737052942642, 'max_depth': 12, 'reg_alpha': 0.0009040884568982261, 'reg_lambda': 5.889870175124454, 'feature_fraction': 0.6664289643882277, 'bagging_fraction': 0.5580546342887509, 'bagging_freq': 5, 'min_data_in_leaf': 200}. Best is trial 4 with value: 1.487852109768669.
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 1.48977
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 1.48851
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 1.50222
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 1.47925
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [498]	valid's rmse: 1.48298
# [I 2025-06-14 17:31:50,066] Trial 7 finished with value: 1.4885446771280137 and parameters: {'num_leaves': 149, 'learning_rate': 0.021584729121977998, 'max_depth': 12, 'reg_alpha': 7.376024827825465, 'reg_lambda': 0.0008077586571489891, 'feature_fraction': 0.6648231984664661, 'bagging_fraction': 0.8036760300859622, 'bagging_freq': 5, 'min_data_in_leaf': 204}. Best is trial 4 with value: 1.487852109768669.
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 1.50096
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 1.49946
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [497]	valid's rmse: 1.51179
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [497]	valid's rmse: 1.48815
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 1.49261
# [I 2025-06-14 17:33:01,816] Trial 8 finished with value: 1.498595507911619 and parameters: {'num_leaves': 107, 'learning_rate': 0.027521448316098446, 'max_depth': 10, 'reg_alpha': 0.004026360901338699, 'reg_lambda': 0.000305705563511273, 'feature_fraction': 0.9006505683344346, 'bagging_fraction': 0.4151335109209015, 'bagging_freq': 2, 'min_data_in_leaf': 432}. Best is trial 4 with value: 1.487852109768669.
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 1.685
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 1.69591
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 1.70444
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 1.68975
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 1.67919
# [I 2025-06-14 17:33:59,046] Trial 9 finished with value: 1.6908583552337244 and parameters: {'num_leaves': 26, 'learning_rate': 0.0024446594456802922, 'max_depth': 7, 'reg_alpha': 0.001499402648929466, 'reg_lambda': 0.006244650388242344, 'feature_fraction': 0.4870981102803031, 'bagging_fraction': 0.4813828127928418, 'bagging_freq': 1, 'min_data_in_leaf': 92}. Best is trial 4 with value: 1.487852109768669.
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 1.50895
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 1.50906
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 1.52154
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 1.49998
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 1.5034
# [I 2025-06-14 17:35:04,340] Trial 10 finished with value: 1.5085869568209456 and parameters: {'num_leaves': 67, 'learning_rate': 0.019958650033540908, 'max_depth': 5, 'reg_alpha': 0.3235833597338905, 'reg_lambda': 0.3096361937688201, 'feature_fraction': 0.9529539423814751, 'bagging_fraction': 0.758504606317353, 'bagging_freq': 7, 'min_data_in_leaf': 347}. Best is trial 4 with value: 1.487852109768669.
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 17:35:08,370] Trial 11 pruned. Trial was pruned at iteration 50.
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 17:35:11,031] Trial 12 pruned. Trial was pruned at iteration 50.
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 1.49377
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 1.49329
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [475]	valid's rmse: 1.50571
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [477]	valid's rmse: 1.48641
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 1.48503
# [I 2025-06-14 17:36:37,022] Trial 13 finished with value: 1.4928416420450012 and parameters: {'num_leaves': 65, 'learning_rate': 0.04052941448401584, 'max_depth': 12, 'reg_alpha': 0.17424112645795228, 'reg_lambda': 0.3607222298392973, 'feature_fraction': 0.7655023821774583, 'bagging_fraction': 0.8570248648067327, 'bagging_freq': 6, 'min_data_in_leaf': 24}. Best is trial 4 with value: 1.487852109768669.
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 17:36:39,286] Trial 14 pruned. Trial was pruned at iteration 50.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [155]	valid's rmse: 1.49676
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [188]	valid's rmse: 1.49426
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [240]	valid's rmse: 1.50739
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [229]	valid's rmse: 1.48642
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [169]	valid's rmse: 1.48838
# [I 2025-06-14 17:37:40,961] Trial 15 finished with value: 1.494645069936692 and parameters: {'num_leaves': 149, 'learning_rate': 0.09475105415437622, 'max_depth': 11, 'reg_alpha': 0.03352448787564095, 'reg_lambda': 0.07761277023593155, 'feature_fraction': 0.7232234756988024, 'bagging_fraction': 0.8718391173030449, 'bagging_freq': 3, 'min_data_in_leaf': 234}. Best is trial 4 with value: 1.487852109768669.
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 1.49068
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 1.48803
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [498]	valid's rmse: 1.50047
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [497]	valid's rmse: 1.47957
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 1.48357
# [I 2025-06-14 17:39:43,683] Trial 16 finished with value: 1.4884646310233007 and parameters: {'num_leaves': 104, 'learning_rate': 0.03818029247511332, 'max_depth': 10, 'reg_alpha': 0.03881803717055303, 'reg_lambda': 1.7087530489429836, 'feature_fraction': 0.8624086565552432, 'bagging_fraction': 0.9987561539929737, 'bagging_freq': 5, 'min_data_in_leaf': 355}. Best is trial 4 with value: 1.487852109768669.
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 1.49062
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 1.48824
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [477]	valid's rmse: 1.50142
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [471]	valid's rmse: 1.47983
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [495]	valid's rmse: 1.48239
# [I 2025-06-14 17:41:41,859] Trial 17 finished with value: 1.488498790283688 and parameters: {'num_leaves': 102, 'learning_rate': 0.044066413778027114, 'max_depth': 10, 'reg_alpha': 0.04409971102501254, 'reg_lambda': 1.7387104652891574, 'feature_fraction': 0.8677961225504781, 'bagging_fraction': 0.9942611787542295, 'bagging_freq': 7, 'min_data_in_leaf': 376}. Best is trial 4 with value: 1.487852109768669.
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 17:41:44,714] Trial 18 pruned. Trial was pruned at iteration 50.
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 17:41:48,592] Trial 19 pruned. Trial was pruned at iteration 50.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [425]	valid's rmse: 1.4943
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [491]	valid's rmse: 1.48819
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [481]	valid's rmse: 1.5048
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 1.48055
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [495]	valid's rmse: 1.48573
# [I 2025-06-14 17:43:20,323] Trial 20 finished with value: 1.490713496699796 and parameters: {'num_leaves': 79, 'learning_rate': 0.04156135422160461, 'max_depth': 8, 'reg_alpha': 0.006249872297787182, 'reg_lambda': 1.4215490631114536, 'feature_fraction': 0.9223791325542965, 'bagging_fraction': 0.7414704672940733, 'bagging_freq': 5, 'min_data_in_leaf': 256}. Best is trial 4 with value: 1.487852109768669.
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 1.49212
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [455]	valid's rmse: 1.48793
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [479]	valid's rmse: 1.50148
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [495]	valid's rmse: 1.48002
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [448]	valid's rmse: 1.48164
# [I 2025-06-14 17:45:18,826] Trial 21 finished with value: 1.488640757556451 and parameters: {'num_leaves': 100, 'learning_rate': 0.04310706690052237, 'max_depth': 10, 'reg_alpha': 0.05427047652018717, 'reg_lambda': 2.6498129468563145, 'feature_fraction': 0.8625946133430225, 'bagging_fraction': 0.9913017286795021, 'bagging_freq': 7, 'min_data_in_leaf': 366}. Best is trial 4 with value: 1.487852109768669.
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 17:45:21,751] Trial 22 pruned. Trial was pruned at iteration 50.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [426]	valid's rmse: 1.49106
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [431]	valid's rmse: 1.48758
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [487]	valid's rmse: 1.50263
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [436]	valid's rmse: 1.47754
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [483]	valid's rmse: 1.48188
# [I 2025-06-14 17:47:13,579] Trial 23 finished with value: 1.4881385432349137 and parameters: {'num_leaves': 101, 'learning_rate': 0.056812966932488836, 'max_depth': 11, 'reg_alpha': 0.893824260573108, 'reg_lambda': 3.7912561002601266, 'feature_fraction': 0.729990454239545, 'bagging_fraction': 0.966135836281663, 'bagging_freq': 6, 'min_data_in_leaf': 319}. Best is trial 4 with value: 1.487852109768669.
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 17:47:16,301] Trial 24 pruned. Trial was pruned at iteration 50.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [279]	valid's rmse: 1.49435
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [308]	valid's rmse: 1.48784
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [312]	valid's rmse: 1.50334
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [397]	valid's rmse: 1.48215
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [392]	valid's rmse: 1.48414
# [I 2025-06-14 17:48:47,981] Trial 25 finished with value: 1.490363202910468 and parameters: {'num_leaves': 93, 'learning_rate': 0.06657516082328441, 'max_depth': 11, 'reg_alpha': 0.6261448676586169, 'reg_lambda': 0.47676444371798626, 'feature_fraction': 0.8096623788648797, 'bagging_fraction': 0.9501450310713275, 'bagging_freq': 5, 'min_data_in_leaf': 244}. Best is trial 4 with value: 1.487852109768669.
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 17:48:51,745] Trial 26 pruned. Trial was pruned at iteration 50.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [163]	valid's rmse: 1.5004
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [239]	valid's rmse: 1.49592
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 17:49:19,099] Trial 27 pruned. Trial was pruned at iteration 362.
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 17:49:20,730] Trial 28 pruned. Trial was pruned at iteration 50.
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 17:49:22,710] Trial 29 pruned. Trial was pruned at iteration 50.
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [495]	valid's rmse: 1.49157
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 1.48872
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 1.50236
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [497]	valid's rmse: 1.48076
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 1.48201
# [I 2025-06-14 17:50:41,474] Trial 30 finished with value: 1.4890830281624405 and parameters: {'num_leaves': 71, 'learning_rate': 0.04779567044672343, 'max_depth': 7, 'reg_alpha': 2.4078939705128386, 'reg_lambda': 0.7185389670964681, 'feature_fraction': 0.5505013857864027, 'bagging_fraction': 0.8896403664182536, 'bagging_freq': 4, 'min_data_in_leaf': 205}. Best is trial 4 with value: 1.487852109768669.
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [476]	valid's rmse: 1.49135
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 1.48605
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [426]	valid's rmse: 1.50285
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [483]	valid's rmse: 1.48032
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [440]	valid's rmse: 1.48258
# [I 2025-06-14 17:52:41,587] Trial 31 finished with value: 1.488629765491218 and parameters: {'num_leaves': 105, 'learning_rate': 0.05145471958032991, 'max_depth': 10, 'reg_alpha': 0.03507586663488693, 'reg_lambda': 2.0575079589254304, 'feature_fraction': 0.8873617394319757, 'bagging_fraction': 0.9752241231964729, 'bagging_freq': 7, 'min_data_in_leaf': 376}. Best is trial 4 with value: 1.487852109768669.
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 17:52:44,574] Trial 32 pruned. Trial was pruned at iteration 50.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [254]	valid's rmse: 1.49047
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [391]	valid's rmse: 1.49019
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [386]	valid's rmse: 1.49979
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [404]	valid's rmse: 1.48138
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [325]	valid's rmse: 1.48633
# [I 2025-06-14 17:54:17,847] Trial 33 finished with value: 1.4896325225362752 and parameters: {'num_leaves': 88, 'learning_rate': 0.07230652649613632, 'max_depth': 11, 'reg_alpha': 0.015175840141558613, 'reg_lambda': 0.7959392089363032, 'feature_fraction': 0.7608619974975653, 'bagging_fraction': 0.9994953201706074, 'bagging_freq': 7, 'min_data_in_leaf': 340}. Best is trial 4 with value: 1.487852109768669.
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 17:54:21,091] Trial 34 pruned. Trial was pruned at iteration 50.
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 17:54:24,132] Trial 35 pruned. Trial was pruned at iteration 50.
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [473]	valid's rmse: 1.49252
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [482]	valid's rmse: 1.48756
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [473]	valid's rmse: 1.49973
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [365]	valid's rmse: 1.48118
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [344]	valid's rmse: 1.48465
# [I 2025-06-14 17:56:12,510] Trial 36 finished with value: 1.4891262451472573 and parameters: {'num_leaves': 83, 'learning_rate': 0.055828235037328505, 'max_depth': 12, 'reg_alpha': 0.00356360110367794, 'reg_lambda': 0.012158033827930785, 'feature_fraction': 0.8703258712771816, 'bagging_fraction': 0.9494762261910898, 'bagging_freq': 7, 'min_data_in_leaf': 118}. Best is trial 4 with value: 1.487852109768669.
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 17:56:15,380] Trial 37 pruned. Trial was pruned at iteration 50.
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 17:56:33,417] Trial 38 pruned. Trial was pruned at iteration 403.
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 17:56:35,731] Trial 39 pruned. Trial was pruned at iteration 50.
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 17:56:38,142] Trial 40 pruned. Trial was pruned at iteration 50.
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 17:56:43,018] Trial 41 pruned. Trial was pruned at iteration 50.
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 17:56:46,131] Trial 42 pruned. Trial was pruned at iteration 50.
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 17:56:49,504] Trial 43 pruned. Trial was pruned at iteration 50.
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [493]	valid's rmse: 1.49042
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [420]	valid's rmse: 1.48714
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [492]	valid's rmse: 1.50018
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [487]	valid's rmse: 1.47884
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [495]	valid's rmse: 1.48174
# [I 2025-06-14 17:58:36,617] Trial 44 finished with value: 1.487663638763458 and parameters: {'num_leaves': 71, 'learning_rate': 0.052067740093130456, 'max_depth': 12, 'reg_alpha': 1.351501438963958, 'reg_lambda': 0.22733487619093873, 'feature_fraction': 0.6335141587727978, 'bagging_fraction': 0.8944199090503016, 'bagging_freq': 7, 'min_data_in_leaf': 301}. Best is trial 44 with value: 1.487663638763458.
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 17:58:52,224] Trial 45 pruned. Trial was pruned at iteration 396.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [232]	valid's rmse: 1.49669
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [370]	valid's rmse: 1.49078
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [337]	valid's rmse: 1.50337
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [364]	valid's rmse: 1.48405
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [286]	valid's rmse: 1.48583
# [I 2025-06-14 18:00:17,089] Trial 46 finished with value: 1.4921454575264665 and parameters: {'num_leaves': 84, 'learning_rate': 0.08518100220227655, 'max_depth': 9, 'reg_alpha': 0.44994481374417905, 'reg_lambda': 0.5177498714908819, 'feature_fraction': 0.6181049790644353, 'bagging_fraction': 0.9399236746816104, 'bagging_freq': 7, 'min_data_in_leaf': 260}. Best is trial 44 with value: 1.487663638763458.
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 18:00:22,664] Trial 47 pruned. Trial was pruned at iteration 186.
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 18:00:27,627] Trial 48 pruned. Trial was pruned at iteration 50.
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 18:00:29,533] Trial 49 pruned. Trial was pruned at iteration 50.
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 18:00:32,419] Trial 50 pruned. Trial was pruned at iteration 63.
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 18:00:34,828] Trial 51 pruned. Trial was pruned at iteration 50.
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 18:00:40,421] Trial 52 pruned. Trial was pruned at iteration 50.
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 18:00:43,875] Trial 53 pruned. Trial was pruned at iteration 50.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [335]	valid's rmse: 1.49078
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [430]	valid's rmse: 1.48819
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [329]	valid's rmse: 1.50196
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [427]	valid's rmse: 1.47908
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [306]	valid's rmse: 1.48462
# [I 2025-06-14 18:02:55,082] Trial 54 finished with value: 1.4889261243647298 and parameters: {'num_leaves': 126, 'learning_rate': 0.0600358567738296, 'max_depth': 12, 'reg_alpha': 0.10133867771438579, 'reg_lambda': 6.199182525509929, 'feature_fraction': 0.8182222670952902, 'bagging_fraction': 0.8537147463125468, 'bagging_freq': 4, 'min_data_in_leaf': 251}. Best is trial 44 with value: 1.487663638763458.
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 1.48728
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [482]	valid's rmse: 1.48445
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [457]	valid's rmse: 1.50342
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [482]	valid's rmse: 1.47744
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [486]	valid's rmse: 1.47961
# [I 2025-06-14 18:04:58,923] Trial 55 finished with value: 1.4864394968752808 and parameters: {'num_leaves': 101, 'learning_rate': 0.04292898180307971, 'max_depth': 10, 'reg_alpha': 0.025542956569865653, 'reg_lambda': 0.15673246444930028, 'feature_fraction': 0.6882165642805227, 'bagging_fraction': 0.8216530452512524, 'bagging_freq': 6, 'min_data_in_leaf': 224}. Best is trial 55 with value: 1.4864394968752808.
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [464]	valid's rmse: 1.4897
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [495]	valid's rmse: 1.48444
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 1.4993
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [486]	valid's rmse: 1.47866
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [490]	valid's rmse: 1.4805
# [I 2025-06-14 18:07:04,514] Trial 56 finished with value: 1.4865216837231692 and parameters: {'num_leaves': 100, 'learning_rate': 0.0444238348255243, 'max_depth': 10, 'reg_alpha': 0.02589272936373881, 'reg_lambda': 0.164963250759419, 'feature_fraction': 0.6738982099472135, 'bagging_fraction': 0.884140268589999, 'bagging_freq': 6, 'min_data_in_leaf': 230}. Best is trial 55 with value: 1.4864394968752808.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [308]	valid's rmse: 1.49298
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [307]	valid's rmse: 1.48932
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 18:07:53,819] Trial 57 pruned. Trial was pruned at iteration 411.
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 18:07:56,781] Trial 58 pruned. Trial was pruned at iteration 50.
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 18:08:01,453] Trial 59 pruned. Trial was pruned at iteration 50.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [271]	valid's rmse: 1.49305
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [381]	valid's rmse: 1.48821
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [339]	valid's rmse: 1.50743
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [414]	valid's rmse: 1.47981
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [271]	valid's rmse: 1.48744
# [I 2025-06-14 18:09:25,093] Trial 60 finished with value: 1.4911885814125905 and parameters: {'num_leaves': 76, 'learning_rate': 0.06314630002477861, 'max_depth': 10, 'reg_alpha': 0.01003884772512236, 'reg_lambda': 0.12172189365049822, 'feature_fraction': 0.6914880111784741, 'bagging_fraction': 0.7428614852429823, 'bagging_freq': 4, 'min_data_in_leaf': 278}. Best is trial 55 with value: 1.4864394968752808.
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 1.48987
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [490]	valid's rmse: 1.48671
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [498]	valid's rmse: 1.49935
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 1.47778
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 1.48173
# [I 2025-06-14 18:11:18,662] Trial 61 finished with value: 1.4870897742708515 and parameters: {'num_leaves': 103, 'learning_rate': 0.048727082376399146, 'max_depth': 9, 'reg_alpha': 0.04929610495756536, 'reg_lambda': 0.2694304262196287, 'feature_fraction': 0.6409927609683702, 'bagging_fraction': 0.9542325063005551, 'bagging_freq': 7, 'min_data_in_leaf': 299}. Best is trial 55 with value: 1.4864394968752808.
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [488]	valid's rmse: 1.48985
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 1.48741
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [470]	valid's rmse: 1.50247
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [498]	valid's rmse: 1.47829
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [489]	valid's rmse: 1.48202
# [I 2025-06-14 18:13:12,874] Trial 62 finished with value: 1.4880072427972197 and parameters: {'num_leaves': 100, 'learning_rate': 0.047621325191870754, 'max_depth': 9, 'reg_alpha': 0.042530862076781105, 'reg_lambda': 0.2636405912914727, 'feature_fraction': 0.636718806305268, 'bagging_fraction': 0.9182983357935559, 'bagging_freq': 7, 'min_data_in_leaf': 295}. Best is trial 55 with value: 1.4864394968752808.
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 18:13:16,284] Trial 63 pruned. Trial was pruned at iteration 61.
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 18:13:23,516] Trial 64 pruned. Trial was pruned at iteration 162.
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 18:13:29,382] Trial 65 pruned. Trial was pruned at iteration 170.
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 18:13:38,951] Trial 66 pruned. Trial was pruned at iteration 190.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [245]	valid's rmse: 1.49474
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [418]	valid's rmse: 1.48702
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [424]	valid's rmse: 1.50111
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [384]	valid's rmse: 1.48316
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [261]	valid's rmse: 1.4852
# [I 2025-06-14 18:15:02,763] Trial 67 finished with value: 1.4902446822105262 and parameters: {'num_leaves': 67, 'learning_rate': 0.07182676719871017, 'max_depth': 11, 'reg_alpha': 0.025055367431034196, 'reg_lambda': 0.08087825007157605, 'feature_fraction': 0.6034034187515255, 'bagging_fraction': 0.8945855992307203, 'bagging_freq': 2, 'min_data_in_leaf': 284}. Best is trial 55 with value: 1.4864394968752808.
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 18:15:05,522] Trial 68 pruned. Trial was pruned at iteration 50.
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 18:15:10,233] Trial 69 pruned. Trial was pruned at iteration 50.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [408]	valid's rmse: 1.49006
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [436]	valid's rmse: 1.48612
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [492]	valid's rmse: 1.49877
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [498]	valid's rmse: 1.47755
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [444]	valid's rmse: 1.48381
# [I 2025-06-14 18:17:16,983] Trial 70 finished with value: 1.487262169424283 and parameters: {'num_leaves': 102, 'learning_rate': 0.051129116319072895, 'max_depth': 11, 'reg_alpha': 0.011796235859904329, 'reg_lambda': 0.2769287454470775, 'feature_fraction': 0.7175820172511342, 'bagging_fraction': 0.9524931610756455, 'bagging_freq': 7, 'min_data_in_leaf': 340}. Best is trial 55 with value: 1.4864394968752808.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [407]	valid's rmse: 1.49025
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [499]	valid's rmse: 1.48821
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [499]	valid's rmse: 1.49996
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [483]	valid's rmse: 1.47711
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [449]	valid's rmse: 1.48116
# [I 2025-06-14 18:19:22,401] Trial 71 finished with value: 1.487338019043257 and parameters: {'num_leaves': 103, 'learning_rate': 0.05328237529333939, 'max_depth': 11, 'reg_alpha': 0.010737670374014182, 'reg_lambda': 0.3124308905240412, 'feature_fraction': 0.7218159255598443, 'bagging_fraction': 0.9561745457465114, 'bagging_freq': 7, 'min_data_in_leaf': 348}. Best is trial 55 with value: 1.4864394968752808.
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 18:19:26,719] Trial 72 pruned. Trial was pruned at iteration 50.
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [497]	valid's rmse: 1.48896
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 1.48845
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 1.50297
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [483]	valid's rmse: 1.47932
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [477]	valid's rmse: 1.48266
# [I 2025-06-14 18:21:09,758] Trial 73 finished with value: 1.4884724357174588 and parameters: {'num_leaves': 114, 'learning_rate': 0.050625792996110246, 'max_depth': 10, 'reg_alpha': 0.010324170480334722, 'reg_lambda': 0.058130347011825914, 'feature_fraction': 0.7035076946877902, 'bagging_fraction': 0.8793993689045353, 'bagging_freq': 7, 'min_data_in_leaf': 360}. Best is trial 55 with value: 1.4864394968752808.
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 18:21:12,401] Trial 74 pruned. Trial was pruned at iteration 50.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [244]	valid's rmse: 1.4942
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [433]	valid's rmse: 1.48763
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [388]	valid's rmse: 1.5043
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [364]	valid's rmse: 1.48221
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [393]	valid's rmse: 1.48234
# [I 2025-06-14 18:22:41,038] Trial 75 finished with value: 1.490135346413222 and parameters: {'num_leaves': 87, 'learning_rate': 0.06859863884400902, 'max_depth': 10, 'reg_alpha': 0.0190965675243989, 'reg_lambda': 0.32024215577677523, 'feature_fraction': 0.6756985872221457, 'bagging_fraction': 0.9273826740870816, 'bagging_freq': 7, 'min_data_in_leaf': 336}. Best is trial 55 with value: 1.4864394968752808.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [228]	valid's rmse: 1.49215
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [270]	valid's rmse: 1.49025
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [257]	valid's rmse: 1.50494
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [257]	valid's rmse: 1.48401
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [287]	valid's rmse: 1.48538
# [I 2025-06-14 18:24:09,970] Trial 76 finished with value: 1.4913449795470637 and parameters: {'num_leaves': 106, 'learning_rate': 0.08595752869155326, 'max_depth': 12, 'reg_alpha': 0.03707260175867804, 'reg_lambda': 0.1332807937131206, 'feature_fraction': 0.7454399432400808, 'bagging_fraction': 0.95530047842058, 'bagging_freq': 7, 'min_data_in_leaf': 292}. Best is trial 55 with value: 1.4864394968752808.
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 18:24:15,896] Trial 77 pruned. Trial was pruned at iteration 127.
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 18:24:34,649] Trial 78 pruned. Trial was pruned at iteration 403.
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 18:24:37,717] Trial 79 pruned. Trial was pruned at iteration 50.
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 18:24:40,286] Trial 80 pruned. Trial was pruned at iteration 50.
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 18:24:45,361] Trial 81 pruned. Trial was pruned at iteration 50.
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 18:24:50,092] Trial 82 pruned. Trial was pruned at iteration 118.
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 18:24:53,345] Trial 83 pruned. Trial was pruned at iteration 50.
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 18:24:57,108] Trial 84 pruned. Trial was pruned at iteration 50.
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 18:25:00,479] Trial 85 pruned. Trial was pruned at iteration 50.
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 18:25:14,166] Trial 86 pruned. Trial was pruned at iteration 258.
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 18:25:16,837] Trial 87 pruned. Trial was pruned at iteration 50.
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 18:25:34,887] Trial 88 pruned. Trial was pruned at iteration 393.
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 18:25:38,344] Trial 89 pruned. Trial was pruned at iteration 50.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [231]	valid's rmse: 1.49436
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [338]	valid's rmse: 1.48676
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [345]	valid's rmse: 1.50467
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [214]	valid's rmse: 1.48382
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [301]	valid's rmse: 1.4827
# [I 2025-06-14 18:27:08,627] Trial 90 finished with value: 1.4904635652449065 and parameters: {'num_leaves': 105, 'learning_rate': 0.06971957659353896, 'max_depth': 12, 'reg_alpha': 0.08291766783493293, 'reg_lambda': 0.4966408936000765, 'feature_fraction': 0.7062305330600387, 'bagging_fraction': 0.9286595046173073, 'bagging_freq': 7, 'min_data_in_leaf': 245}. Best is trial 55 with value: 1.4864394968752808.
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 18:27:13,550] Trial 91 pruned. Trial was pruned at iteration 50.
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 18:27:16,456] Trial 92 pruned. Trial was pruned at iteration 50.
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [487]	valid's rmse: 1.48923
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [458]	valid's rmse: 1.48477
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [495]	valid's rmse: 1.50211
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [491]	valid's rmse: 1.47757
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [430]	valid's rmse: 1.48051
# [I 2025-06-14 18:29:21,518] Trial 93 finished with value: 1.4868394682392456 and parameters: {'num_leaves': 112, 'learning_rate': 0.04930468142188133, 'max_depth': 11, 'reg_alpha': 0.030696032561360116, 'reg_lambda': 0.23235484464248443, 'feature_fraction': 0.7340578949233199, 'bagging_fraction': 0.9874070281957776, 'bagging_freq': 6, 'min_data_in_leaf': 306}. Best is trial 55 with value: 1.4864394968752808.
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [480]	valid's rmse: 1.48972
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [479]	valid's rmse: 1.48576
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [478]	valid's rmse: 1.5019
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [474]	valid's rmse: 1.48053
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [479]	valid's rmse: 1.48203
# [I 2025-06-14 18:31:17,450] Trial 94 finished with value: 1.4879863768787973 and parameters: {'num_leaves': 112, 'learning_rate': 0.04812845415313839, 'max_depth': 11, 'reg_alpha': 0.01929913775794487, 'reg_lambda': 0.2409030776687041, 'feature_fraction': 0.7361304460712766, 'bagging_fraction': 0.9008014507930258, 'bagging_freq': 6, 'min_data_in_leaf': 301}. Best is trial 55 with value: 1.4864394968752808.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [322]	valid's rmse: 1.49164
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [499]	valid's rmse: 1.48589
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 1.49963
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [438]	valid's rmse: 1.4799
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 1.48214
# [I 2025-06-14 18:33:04,851] Trial 95 finished with value: 1.4878383032188744 and parameters: {'num_leaves': 112, 'learning_rate': 0.04842274441050265, 'max_depth': 11, 'reg_alpha': 0.05170951746712964, 'reg_lambda': 0.22557391763854007, 'feature_fraction': 0.7132508317553311, 'bagging_fraction': 0.8974951661090504, 'bagging_freq': 6, 'min_data_in_leaf': 306}. Best is trial 55 with value: 1.4864394968752808.
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 18:33:19,292] Trial 96 pruned. Trial was pruned at iteration 321.
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 18:33:34,284] Trial 97 pruned. Trial was pruned at iteration 346.
# Training until validation scores don't improve for 50 rounds
# [I 2025-06-14 18:33:39,008] Trial 98 pruned. Trial was pruned at iteration 50.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [416]	valid's rmse: 1.49071
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [447]	valid's rmse: 1.48611
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [453]	valid's rmse: 1.50475
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [468]	valid's rmse: 1.48
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [413]	valid's rmse: 1.48561
# [I 2025-06-14 18:35:32,268] Trial 99 finished with value: 1.4894326529264377 and parameters: {'num_leaves': 128, 'learning_rate': 0.0554076029053661, 'max_depth': 11, 'reg_alpha': 0.01009066473106625, 'reg_lambda': 1.1444834275572588, 'feature_fraction': 0.7483543834195705, 'bagging_fraction': 0.8209989607288625, 'bagging_freq': 6, 'min_data_in_leaf': 315}. Best is trial 55 with value: 1.4864394968752808.

# %%
model, test_rmse= training(X, y,
    params_json_path="exp_all_best_params.json",
    save_model_path='exp_all_model.txt',
    save_log_filename="exp_all_log.csv")
# Out:
# Training until validation scores don't improve for 50 rounds
# [50]	valid's rmse: 1.55641	valid's l2: 2.4224
# [100]	valid's rmse: 1.52016	valid's l2: 2.31089
# [150]	valid's rmse: 1.51079	valid's l2: 2.28247
# [200]	valid's rmse: 1.50706	valid's l2: 2.27122
# [250]	valid's rmse: 1.50487	valid's l2: 2.26462
# [300]	valid's rmse: 1.50306	valid's l2: 2.25918
# [350]	valid's rmse: 1.50214	valid's l2: 2.25644
# [400]	valid's rmse: 1.50153	valid's l2: 2.25458
# [450]	valid's rmse: 1.50083	valid's l2: 2.2525
# [500]	valid's rmse: 1.50092	valid's l2: 2.25277
# Early stopping, best iteration is:
# [466]	valid's rmse: 1.50054	valid's l2: 2.25163

# %%
# Compute the standard deviation of y
std_y = y.std()
print(f"The standard deviation of y is: {std_y}")
# Out:
# The standard deviation of y is: 2.0820203194668627

# %%
evaluation(model,
    X.sample(10000),
    name = "exp_all_results",
    max_display=30)
